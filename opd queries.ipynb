# %%
# %%spark -c sql
# --non customer metrics by week
# select wm_yr_wk_nbr,
# sum(og.order_ty_cnt) AS orders_tw,
# sum(og.order_lw_cnt) AS orders_lw,
# sum(og.dlvr_ty_amt) AS gmv_tw,
# sum(og.dlvr_lw_amt) AS gmv_lw,
# sum(og.visit_ty_cnt) AS visits_tw,
# sum(og.visit_lw_cnt) AS visits_lw
# from ww_mktg_dl_tables.mktg_onln_groc_dly_summ og
# where mktg_chnl_nm = 'ALL'
# and sub_mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and store_nbr = '-999'
# and dma_nm = 'ALL'
# and cust_type_nm = 'ALL'
# and rpt_dt between '2021-12-04' and '2021-12-06'
# group by wm_yr_wk_nbr
# order by wm_yr_wk_nbr
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    wm_yr_wk_nbr  orders_tw  orders_lw        gmv_tw        gmv_lw  visits_tw  \
# 0            45    2114906    2025179  2.127538e+08  1.866093e+08   90365872
#
#    visits_lw
# 0  104868474

# %%
# %%spark -c sql
# --non customer metrics by rpt_dt
# select rpt_dt, wm_yr_wk_nbr,
# sum(og.order_ty_cnt) AS orders_tw,
# sum(og.order_lw_cnt) AS orders_lw,
# sum(og.dlvr_ty_amt) AS gmv_tw,
# sum(og.dlvr_lw_amt) AS gmv_lw,
# sum(og.visit_ty_cnt) AS visits_tw,
# sum(og.visit_lw_cnt) AS visits_lw
# from ww_mktg_dl_tables.mktg_onln_groc_dly_summ og
# where mktg_chnl_nm = 'ALL'
# and sub_mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and store_nbr = '-999'
# and dma_nm = 'ALL'
# and cust_type_nm = 'ALL'
# and rpt_dt between '2021-11-25' and '2021-11-26'
# group by rpt_dt,wm_yr_wk_nbr
# order by rpt_dt,wm_yr_wk_nbr
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#       rpt_dt  wm_yr_wk_nbr  orders_tw  orders_lw        gmv_tw        gmv_lw  \
# 0 2021-11-25            43         43     614126  4.604246e+03  6.022921e+07
# 1 2021-11-26            43     438577     687180  3.690854e+07  7.133866e+07
#
#    visits_tw  visits_lw
# 0   28832920   24851428
# 1   45876738   23450941

# %%
# When data for partial week, fetch data from daily customer count table: ww_mktg_dl_tables.mktg_onln_groc_dly_summ

# do NOT validate against: ww_mktg_dl_tables.mktg_onln_groc_cust_dly_summ. 
# This table has cumulative incremental values for different time frame :Weekly, Quarter and Yearly level.

# Partial week: WMT week starts on Saturday and Ends on Friday

# %%
# %%spark -c sql
# -- for COMPLETE WEEK use ww_mktg_dl_tables.mktg_onln_groc_cust_dly_summ for customer count
# --customer metrics for complete week is a cumulative number
# -- so for the week the max date will have the customer count for the complete week
#
# select rpt_dt,wm_yr_wk_nbr,cust_type_nm,sum(cust_cnt) as new_cust
# from ww_mktg_dl_tables.mktg_onln_groc_cust_dly_summ
# where mktg_chnl_nm = 'ALL'
# and sub_mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and dma_nm = 'ALL'
# and period_beg_nm = 'WEEKLY'
# and cust_type_nm = 'NEW CUSTOMER'
# and rpt_dt between '2021-11-13' and '2021-11-19'
# group by rpt_dt,wm_yr_wk_nbr,cust_type_nm
# order by rpt_dt,wm_yr_wk_nbr,cust_type_nm
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#       rpt_dt  wm_yr_wk_nbr  cust_type_nm  new_cust
# 0 2021-11-13            42  NEW CUSTOMER     26441
# 1 2021-11-14            42  NEW CUSTOMER     51517
# 2 2021-11-15            42  NEW CUSTOMER     76643
# 3 2021-11-16            42  NEW CUSTOMER    100568
# 4 2021-11-17            42  NEW CUSTOMER    123887
# 5 2021-11-18            42  NEW CUSTOMER    146646
# 6 2021-11-19            42  NEW CUSTOMER    170958

# %%
# %%spark -c sql
# -- FOR PARTIAL WEEK customer count use ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# select sum(cust_ty_cnt) as total_cust_counts_tw
# from
# ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where
# store_nbr = -999
# and dma_nm = 'ALL'
# and mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and cust_type_nm = 'NEW CUSTOMER'
# and rpt_dt between '2021-11-27' and '2021-12-02'
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    total_cust_counts_tw
# 0                269633

# %%
# %%spark -c sql
# -- FOR PARTIAL WEEK customer count use ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# select rpt_dt,sum(cust_ty_cnt) as total_cust_counts_tw
# from
# ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where
# store_nbr = -999
# and dma_nm = 'ALL'
# and mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and cust_type_nm = 'NEW CUSTOMER'
# and rpt_dt between '2021-11-27' and '2021-12-02'
# group by rpt_dt
# order by rpt_dt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#       rpt_dt  total_cust_counts_tw
# 0 2021-11-27                 50916
# 1 2021-11-28                 42412
# 2 2021-11-29                 49176
# 3 2021-11-30                 47044
# 4 2021-12-01                 41782
# 5 2021-12-02                 38303

# %%
# %%spark -c sql
# -- FOR PARTIAL WEEK customer count use ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# select sum(cust_ty_cnt) as total_cust_counts_lw
# from
# ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where
# store_nbr = -999
# and dma_nm = 'ALL'
# and mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and cust_type_nm = 'NEW CUSTOMER'
# and rpt_dt between date_sub('2021-11-20',7) and date_sub('2021-11-20',7)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    total_cust_counts_lw
# 0                 25844

# %%
# %%spark -c sql
# -- FOR PREVIOUS day, DOD customer count use ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# select rpt_dt,sum(cust_ty_cnt) cust_cnt
# from
# ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where
# store_nbr = -999
# and dma_nm = 'ALL'
# and mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and cust_type_nm = 'NEW CUSTOMER'
# and rpt_dt  in('2021-11-20', date_sub('2021-11-20',1))
# group by rpt_dt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#       rpt_dt  cust_cnt
# 0 2021-11-20     26358
# 1 2021-11-19     24352

# %%
# %%spark -c sql
# -- FOR PREVIOUS day, WOW customer count use ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# select rpt_dt,sum(cust_ty_cnt) cust_cnt
# from
# ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where
# store_nbr = -999
# and dma_nm = 'ALL'
# and mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and cust_type_nm = 'NEW CUSTOMER'
# and rpt_dt  in('2021-11-20', date_sub('2021-11-20',7))
# group by rpt_dt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#       rpt_dt  cust_cnt
# 0 2021-11-13     25844
# 1 2021-11-20     26358

# %%
# %%spark -c sql
# -- FOR PREVIOUS day, WOW customer count use ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# select sum(cust_ty_cnt) cust_cnt
# from
# ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where
# store_nbr = -999
# and dma_nm = 'ALL'
# and mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and cust_type_nm = 'NEW CUSTOMER'
# and rpt_dt  between '2021-11-13' and '2021-11-19'
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    cust_cnt
# 0    458178

# %%
# %%spark -c sql
# -- FOR PREVIOUS day, WOW customer count use ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# select sum(cust_ty_cnt) cust_cnt
# from
# ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where
# store_nbr = -999
# and dma_nm = 'ALL'
# and mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and cust_type_nm = 'NEW CUSTOMER'
# and rpt_dt  between '2020-11-01' and '2020-11-19'
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    cust_cnt
# 0    621082

# %%
# %%spark -c sql
# select fiscal_week,
# sum(spend) as spend
# from mktg_spend_mart.mktg_opd_spend
# where day between '2021-11-13' and '2021-11-19'
# group by fiscal_week
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#     fiscal_week      spend
# 0  FY21 Week 42  669592.89
# 1  FY21 Week 41  173475.80

# %%
# %%spark -c sql
# -- get spend numbers
# select fiscal_week,
# sum(spend) as spend
# from mktg_spend_mart.mktg_opd_spend
# where to_date(day) between '2021-11-27' and '2021-12-02'
# group by fiscal_week
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#     fiscal_week      spend
# 0  FY22 Week 44  763796.08

# %%
# %%spark -c sql
# -- get spend numbers by spend tactic pillar
# select to_date(day) as dt,fiscal_week, 'ALL' as marketing_vehicle,
# spend_tactic_pillars,
# sum(spend) as spend
# from mktg_spend_mart.mktg_opd_spend
# where to_date(day) between '2021-08-07' and '2021-08-13'
# group by day, fiscal_week,spend_tactic_pillars
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#            dt   fiscal_week marketing_vehicle spend_tactic_pillars      spend
# 0  2021-08-07  FY22 Week 28               ALL            Retention   35197.08
# 1  2021-08-07  FY22 Week 28               ALL        Consideration    6508.67
# 2  2021-08-10  FY22 Week 28               ALL        Consideration   34167.73
# 3  2021-08-11  FY22 Week 28               ALL            Retention   36343.61
# 4  2021-08-08  FY22 Week 28               ALL                  TBD       0.00
# 5  2021-08-11  FY22 Week 28               ALL        Consideration   34255.67
# 6  2021-08-07  FY22 Week 28               ALL          Acquisition  147178.88
# 7  2021-08-13  FY22 Week 28               ALL          Acquisition  157779.63
# 8  2021-08-09  FY22 Week 28               ALL        Consideration   34253.29
# 9  2021-08-09  FY22 Week 28               ALL            Awareness        NaN
# ...

# %%
# %%bigquery
# select rpt_dt, sum(DLVR_AMT) as gmv,count(distinct sales_order_num) as orders
# from wmt-edw-prod.WW_GEC_VM.OG_ORDER_ITEM_360
# where rpt_dt between '2021-10-16' and '2021-10-22'
# and FULFMT_TYPE_DESC  not like 'UNSCHEDULED%' group by rpt_dt order by rpt_dt

# %%
# %%spark -c sql
# -- We do not maintain this hive table and use the bigquery table wmt-edw-prod.WW_GEC_VM.OG_ORDER_ITEM_360
# -- for qc use the bigquery table
# select wm_year_wk_nbr,sum(DLVR_AMT) as gmv,count(distinct sales_order_num) as orders
# from cbb_segment.og_order_item_360 a
# join us_core_dim.calendar_dim b
# on a.rpt_dt=b.calendar_date
# where rpt_dt between '2021-10-09' and '2021-10-22'
# and FULFMT_TYPE_DESC  not like 'UNSCHEDULED%'
# group by wm_year_wk_nbr
# order by wm_year_wk_nbr

# %%
# %%spark -c sql
# Select date1, count(distinct  sales_order_num) as orders_tw
# from sam_tab.all_adid_change
# where date1 between '2021-10-09' and '2021-10-15'
# group by date1
# order by date1
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#        date1  orders_tw
# 0 2021-10-09     585739
# 1 2021-10-10     646218
# 2 2021-10-11     617115
# 3 2021-10-12     478217
# 4 2021-10-13     567898
# 5 2021-10-14     562249
# 6 2021-10-15     636587

# %%
# %%spark -c sql
# -- WEEK TO DATE - Total Orders - Orders TW - Working:
# -- User needs to pass Latest Data Available Date from Dashboard
# -- Check mktg-opd-alerts for Tableau Refresh Complete Notification
# -- **************************************************
# select wm_yr_wk_nbr,
# sum(order_ty_cnt) cust_orders,
# sum(dlvr_ty_amt) AS gmv,
# sum(visit_ty_cnt) AS visits
# from ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where mktg_chnl_nm = 'ALL'
# and sub_mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and store_nbr = '-999'
# and dma_nm = 'ALL'
# and cust_type_nm = 'ALL' -- REPEAT CUSTOMER/NEW CUSTOMER/ALL
# and wm_yr_wk_nbr = (select max(wm_yr_wk_nbr)
# from ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where rpt_dt = '2021-11-20')
# and year(rpt_dt) = year('2021-11-20')
# group by wm_yr_wk_nbr
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    wm_yr_wk_nbr  cust_orders           gmv    visits
# 0            43       678316  6.920269e+07  27954204

# %%
# %%spark -c sql
# -- check for row count for ww_mktg_dl_tables.mktg_onln_groc_cust_dly_summ , in case there are multiple rows
# select
# rpt_dt,
# period_beg_nm,
# mktg_chnl_nm AS mktg_chnl,
# sub_mktg_chnl_nm AS sub_mkt_chnl,
# dev_type_nm AS dev_type,
# fulfmt_chnl_nm AS fulfmt_chnl,
# dma_nm AS dma_nm,
# cust_type_nm AS cust_type,
# cust_cnt AS cust_prev_qtr,
# COUNT(*) OVER(PARTITION BY rpt_dt, period_beg_nm ) row_cnt
# from
# ww_mktg_dl_tables.mktg_onln_groc_cust_dly_summ
# where
# --period_beg_nm in ('QUARTERLY', 'YEARLY')
# dma_nm = 'ALL'
# and mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and cust_type_nm = 'NEW CUSTOMER'
# --and rpt_dt in('2021-11-04', '2020-11-19')
# order by row_cnt DESC
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#          rpt_dt period_beg_nm mktg_chnl sub_mkt_chnl dev_type fulfmt_chnl  \
# 0    2018-08-15     QUARTERLY       ALL          ALL      ALL         ALL
# 1    2018-09-11        WEEKLY       ALL          ALL      ALL         ALL
# 2    2018-11-25        WEEKLY       ALL          ALL      ALL         ALL
# 3    2019-11-25     QUARTERLY       ALL          ALL      ALL         ALL
# 4    2020-07-26        YEARLY       ALL          ALL      ALL         ALL
# ...         ...           ...       ...          ...      ...         ...
# 2495 2018-02-12        YEARLY       ALL          ALL      ALL         ALL
# 2496 2018-04-01       MONTHLY       ALL          ALL      ALL         ALL
# 2497 2018-04-08        WEEKLY       ALL          ALL      ALL         ALL
# 2498 2018-06-28       MONTHLY       ALL          ALL      ALL         ALL
# ...

# %%
# %%spark -c sql
# -- check for glass table mktg_analytics.opd_glass_visits_orders
# select  wm_week, glass_filter,mv, sum(visits)v
# from mktg_analytics.opd_glass_visits_orders  where wm_week >= 202142 and mv ='ALL' and glass_filter = 'overall'
# group by wm_week, glass_filter,mv
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    wm_week glass_filter   mv          v
# 0   202143      overall  ALL   26493914
# 1   202142      overall  ALL  172886897

# %%
# %%spark -c sql
# -- get spend numbers
# select *
# from mktg_spend_mart.mktg_opd_spend
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#        fiscal_week        day marketing_vehicle  \
# 0      FY21 Week 4 2020-02-26               DPS
# 1      FY21 Week 4 2020-02-26               DPS
# 2      FY21 Week 4 2020-02-26               DPS
# 3      FY21 Week 4 2020-02-26               DPS
# 4      FY21 Week 4 2020-02-26               DPS
# ...            ...        ...               ...
# 2495  FY21 Week 32 2020-09-11     OFFLINE MEDIA
# 2496  FY21 Week 32 2020-09-11        AFFILIATES
# 2497  FY21 Week 32 2020-09-11        AFFILIATES
# 2498  FY21 Week 32 2020-09-11        AFFILIATES
# 2499  FY21 Week 32 2020-09-11        AFFILIATES
#
#                               vendor                       channel  \
# 0                                NCM      Digital_Multiple_Display
# 1                           Facebook                        Social
# 2     Haworth Internal Trading - TTD  Digital_Multiple_High_Impact
# ...

# %%
# %%spark -c sql
# --non customer metrics by rpt_dt
# select rpt_dt, wm_yr_wk_nbr,
# sum(og.order_ty_cnt) AS orders_tw,
# sum(og.dlvr_ty_amt) AS gmv_tw,
# sum(og.visit_ty_cnt) AS visits_tw
# from ww_mktg_dl_tables.mktg_onln_groc_dly_summ og
# where mktg_chnl_nm = 'ALL'
# and sub_mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and store_nbr = '-999'
# and dma_nm = 'ALL'
# and cust_type_nm = 'ALL'
# and rpt_dt in ('2021-11-25','2021-11-26','2020-11-26')
# group by rpt_dt,wm_yr_wk_nbr
# order by rpt_dt,wm_yr_wk_nbr
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#       rpt_dt  wm_yr_wk_nbr  orders_tw        gmv_tw  visits_tw
# 0 2020-11-26            43         24  8.253516e+02    4231145
# 1 2021-11-25            43         43  4.604246e+03   28832920
# 2 2021-11-26            43     438577  3.690854e+07   45876738

# %%
# %%spark -c sql
# -- FOR PARTIAL WEEK customer count use ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# select rpt_dt, sum(cust_ty_cnt) as total_cust_counts_tw
# from
# ww_mktg_dl_tables.mktg_onln_groc_dly_summ
# where
# store_nbr = -999
# and dma_nm = 'ALL'
# and mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and cust_type_nm = 'ALL'
# and rpt_dt in('2021-11-25','2021-11-26','2020-11-26')
# group by rpt_dt
# order by rpt_dt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#       rpt_dt  total_cust_counts_tw
# 0 2020-11-26                    24
# 1 2021-11-25                    43
# 2 2021-11-26                426885

# %%
# %%spark -c sql
# --non customer metrics by rpt_dt
# select rpt_dt, wm_yr_wk_nbr,
# sum(og.dlvr_ty_amt) AS gmv_tw
# from ww_mktg_dl_tables.mktg_onln_groc_dly_summ og
# where mktg_chnl_nm = 'ALL'
# and sub_mktg_chnl_nm = 'ALL'
# and dev_type_nm = 'ALL'
# and fulfmt_chnl_nm = 'ALL'
# and store_nbr = '-999'
# and dma_nm = 'ALL'
# and cust_type_nm = 'ALL'
# and rpt_dt between '2021-11-20' and '2021-11-25'
# group by rpt_dt,wm_yr_wk_nbr
# order by rpt_dt,wm_yr_wk_nbr
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#       rpt_dt  wm_yr_wk_nbr        gmv_tw
# 0 2021-11-20            43  6.923253e+07
# 1 2021-11-21            43  7.276121e+07
# 2 2021-11-22            43  6.928803e+07
# 3 2021-11-23            43  6.736976e+07
# 4 2021-11-24            43  6.425482e+07
# 5 2021-11-25            43  4.604246e+03
